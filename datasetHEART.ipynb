# %% [markdown]
# # import

# %%
# install_packages = True
# if install_packages:
#    %pip install ydata_profiling

# %%
# !pip install --upgrade typeguard

# %%
# !pip install --upgrade ydata_profiling

# %%
import pandas as pd
import typing_extensions
from ydata_profiling import ProfileReport, compare

# %%
df = pd.read_csv("heart_disease_uci-books.csv")
report = ProfileReport(
    df,
    title="Trending Books",
    dataset={
        "description": "This profiling report was generated for the datacamp learning resources.",
        "author": "Satyam Tripathi",
        "copyright_holder": "DataCamp, Inc.",
        "copyright_year": 2023,
        "url": "<https://www.datacamp.com/>",
    },
)
report.to_notebook_iframe()

# %% [markdown]
# ## 1. - Exploratory Data Analysis

# %%
dataset = pd.read_csv('heart_disease_uci.csv')

dataset = dataset.iloc[:, 1:]
#dataset = dataset[["age","sex","trestbps","chol","thalch","ca"]]

# %% [markdown]
# # Clean dataset

# %%
report = ProfileReport(df=dataset, title="Heart disease data")
report.to_file("profile_report.html")

# %% [markdown]
# ## **categoriacal variables**
#
# In this section we analize and transform categorical variables. Indeed the treatment of categorical variables holds a significant role in uncovering patterns, drawing insights, and making informed decisions. Categorical variables, which represent qualitative characteristics, often come in the form of labels or groups rather than numerical values. One essential technique in handling these variables is factorization, a process that transforms categorical labels into a numerical format, facilitating their incorporation into mathematical models.

# %% [markdown]
# In certain analytical contexts, the decision to encode categorical variables as 0, 1, 2 (and potentially 3) is driven by the need to convey the severity or magnitude of a phenomenon. This encoding scheme is particularly relevant when dealing with variables that exhibit an inherent ordinal nature, where the order among categories implies a certain level of intensity or significance.

# %% [markdown]
# ## gender

# %%
dataset = pd.read_csv('heart_disease_uci.csv')

dataset = dataset.iloc[:, 1:]

# %%
#FBS
# 0 == FALSE , 1 == TRUE
dataset['fbs'] = dataset['fbs'].map({False: 0, True: 1})

dataset['fbs'] = pd.to_numeric(dataset['fbs'], errors='coerce')

# %%
#SEX
# 0 == MALE , 1 == FEMALE
dataset['sex'] = dataset['sex'].map({"Male": 0, "Female": 1})

# %%
#EXANG
# 0 == FALSE , 1 == TRUE
dataset['exang'] = dataset['exang'].map({False: 0, True: 1})
dataset['exang'] = pd.to_numeric(dataset['exang'], errors='coerce')

# %%
#restecg
dataset['restecg'] = dataset['restecg'].map({"normal": 0, "st-t abnormality": 1, "lv hypertrophy":2})

# %%
#slope
dataset['slope'] = dataset['slope'].map({"downsloping": 0, "flat": 1, "upsloping":2})

# %%
#cp
dataset['cp'] = dataset['cp'].map({"asymptomatic": 0, "non-anginal": 1, "typical angina":2, "atypical angina": 3})

# %%
#thal
dataset['thal'] = dataset['thal'].map({"normal": 0, "fixed defect": 1, "reversable defect":2})

# %% [markdown]
# ## dubbio paesi: costruire 7 variabili dummies?
#
# chatgpt dice:
#
# Se hai una variabile che rappresenta sette paesi in un dataset e stai considerando la fattorizzazione di questa variabile, la decisione dipende dal contesto e dall'obiettivo della tua analisi. Vediamo alcune considerazioni:
#
# >**Fattorizzazione della Variabile:**
#
# Caso Ordinale: Se i paesi possono essere considerati in un ordine specifico (ad esempio, dal più piccolo al più grande o in base a una qualsiasi caratteristica ordinabile), potresti optare per una fattorizzazione numerica che rifletta tale ordine. Ad esempio, assegnare numeri da 1 a 7 in base a qualche criterio di ordinamento.
#
# Caso Nominali: Se i paesi non hanno un ordine intrinseco, potresti considerare la creazione di variabili dummy (variabili binarie) per ciascun paese. Questo implica la creazione di sette nuove variabili, ognuna corrispondente a un paese, e assegnando il valore 1 alla presenza di quel paese e 0 altrove.
#
# >**Utilità della Variabile:**
#  Valuta l'importanza di questa variabile per il tuo scopo di analisi. Se la variabile paese è rilevante per la tua analisi e può influenzare i risultati, potrebbe essere utile mantenerla. Al contrario, se non è strettamente necessaria per gli obiettivi della tua analisi, potresti decidere di trasformarla in una forma più adatta al tuo modello.
#
# > **Dimensione del Dataset:**
# In un dataset più piccolo, l'aggiunta di sette variabili dummy può essere più gestibile. In un dataset più grande, la presenza di sette paesi potrebbe non avere un impatto significativo sulla complessità complessiva dell'analisi.
#
# In generale, la fattorizzazione dipende dalle tue esigenze analitiche specifiche. Se la variabile paese è fondamentale per la tua analisi, conservarla nella sua forma originale o fattorizzarla in modo appropriato può essere utile. D'altra parte, se non è essenziale o se la complessità aggiuntiva è indesiderata, potresti considerare opzioni alternative come l'uso di variabili dummy.

# %% [markdown]
# ## confronto dataset imputato e non?
#
# dall'analisi si vedono 3 variabili (`thal`,`slope`,`ca`) con 52%,30%,66% missing values
